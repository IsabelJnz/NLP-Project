# %% [markdown]
# EDA Chat GPT Tweets

# %%
# imports
import csv
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly_express as px
import numpy as np
import nltk

# %%
with open('tweets.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    data = [row for row in reader]

df = pd.DataFrame(data)

# %%
df
# Out:
#                             0   \
# 0                    user_name
# 1          Social Media Austin
# 2                zeusJuice.Ξth
# 3                    Tim Davis
# 4       Barnacules Nerdgasm ™️
# ...                        ...
# 107756        (I)(AM)(T)(MOYO)
# 107757                   Green
# 107758     Gabriel Furstenheim
# 107759                  Devang
# 107760         Norman Meuschke
#
#                                                        1   \
# 0                                                    text
# 1       OpenAI introduces ChatGPT Plus, an upgraded an...
# 2       The creator of Gmail says that #ChatGPT will k...
# 3       @LeighWolf Wow. #ChatGPT just another politica...
# 4       @Gurk @MetalJesusRocks @DrunkenMstrPaul This i...
# ...                                                   ...
# 107756  Levels🙏🙏🙏,so happy for the chatGPT team for co...
# 107757  Iterating back-and-forth with tools like #Chat...
# 107758  Russel vs ChatGPT. It's also funny that it tak...
# 107759  Was just wondering is there any difference bet...
# 107760  #ChatGPT and similar #LLM pose a challenge to ...
#
#                                    2   \
# 0                       user_location
# 1                           Austin Tx
# 2                 Fort Lauderdale, FL
# 3
# 4       Click this link to find out 👉
# ...                               ...
# 107756                 Satoshi Island
# 107757                              🍁
# 107758
# 107759                  United States
# 107760             Wuppertal, Germany
#
#                                                        3   \
# 0                                        user_description
# 1         SMsun Austin Tx. Social Media in Austin Tweets!
# 2                     Here, just SCREAMING into the void.
# 3
# 4       Retired Microsoft Windows Developer 🪟 Windows ...
# ...                                                   ...
# 107756  Blockchain Enthusiast || Philanthropist || a S...
# 107757
# 107758  Mathematician and Developer @Amazon. Previousl...
# 107759  passionate by nature, software developer by pr...
# 107760  Postdoc in @GippLab at @uniGoettingen \nPh.D. ...
#
#                                4               5             6   \
# 0                    user_created  user_followers  user_friends
# 1       2012-07-29 23:30:54+00:00          2198.0        1659.0
# 2       2021-07-15 16:01:44+00:00           714.0         391.0
# 3       2022-12-23 20:05:30+00:00            21.0         191.0
# 4       2012-08-16 23:16:47+00:00        111087.0        1977.0
# ...                           ...             ...           ...
# 107756  2013-12-07 16:38:30+00:00          3419.0        4994.0
# 107757  2022-12-03 12:49:13+00:00             3.0          33.0
# 107758  2016-07-09 21:08:52+00:00            80.0          34.0
# 107759  2015-05-19 03:17:06+00:00            15.0          86.0
# 107760  2011-02-22 18:03:52+00:00           149.0         262.0
#
#                      7              8                          9   \
# 0       user_favourites  user_verified                       date
# 1                    29          False  2023-02-01 21:20:10+00:00
# 2                  7714          False  2023-02-01 21:20:00+00:00
# 3                   698          False  2023-02-01 21:19:45+00:00
# 4                120080           True  2023-02-01 21:19:40+00:00
# ...                 ...            ...                        ...
# 107756            16659          False  2022-12-05 17:10:31+00:00
# 107757                3          False  2022-12-05 17:09:22+00:00
# 107758              169          False  2022-12-05 17:09:04+00:00
# 107759              307          False  2022-12-05 17:08:44+00:00
# 107760              451          False  2022-12-05 17:08:20+00:00
#
#                                         10                   11
# 0                                 hashtags               source
# 1       ['ChatGPT', 'OpenAI', 'AI', 'GPT']   Viral Content Buzz
# 2                              ['ChatGPT']      Twitter Web App
# 3                  ['ChatGPT', 'pathetic']   Twitter for iPhone
# 4                              ['Chatgpt']   Twitter for iPhone
# ...                                    ...                  ...
# 107756                                      Twitter for Android
# 107757                         ['ChatGPT']      Twitter Web App
# 107758                         ['ChatGPT']  Twitter for Android
# 107759                 ['ChatGPT', 'GPT3']  Twitter for Android
# 107760                  ['ChatGPT', 'LLM']      Twitter Web App
#
# [107761 rows x 12 columns]

# %%
df.shape
# Out:
# (107761, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107761 entries, 0 to 107760
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       107755 non-null  object
#  1   1       107755 non-null  object
#  2   2       107749 non-null  object
#  3   3       107749 non-null  object
#  4   4       107748 non-null  object
#  5   5       107748 non-null  object
#  6   6       107748 non-null  object
#  7   7       107748 non-null  object
#  8   8       107748 non-null  object
#  9   9       107747 non-null  object
#  10  10      107747 non-null  object
#  11  11      107741 non-null  object
# dtypes: object(12)
# memory usage: 9.9+ MB

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# 0     0.005568
# 1     0.005568
# 2     0.011136
# 3     0.011136
# 4     0.012064
# 5     0.012064
# 6     0.012064
# 7     0.012064
# 8     0.012064
# 9     0.012992
# 10    0.012992
# 11    0.018560
# dtype: float64

# %%
df.describe()
# Out:
#                                        0   \
# count                              107755
# unique                              59183
# top     Best MidJourneyAI Generated Art🤖🎨
# freq                                  815
#
#                                                        1       2       3   \
# count                                              107755  107749  107749
# unique                                             103370   16361   58089
# top     We asked Open AI's #ChatGPT what it thought of...
# freq                                                   24   27113    6173
#
#                                4       5       6       7       8   \
# count                      107748  107748  107748  107748  107748
# unique                      59963   12749    7310   23320      12
# top     2022-08-27 13:00:55+00:00     0.0     2.0       0   False
# freq                          815    1758    1435    2151  104589
#
#                                9            10               11
# count                      107747       107747           107741
# unique                     100775        22551              433
# top     2023-01-31 17:26:00+00:00  ['ChatGPT']  Twitter Web App
# freq                           10        40428            51752
